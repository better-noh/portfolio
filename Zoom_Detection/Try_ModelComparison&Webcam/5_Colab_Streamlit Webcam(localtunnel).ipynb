# %% [markdown]
# ## Try2. Google Colab에서 Streamlit 구현 - localtunnel 활용
# - 참고 - [Run Streamlit App on Colab without Ngrok (LocalTunnel)](https://www.youtube.com/watch?v=NEhrkeF2o_M)
# > - 관련 깃허브: https://github.com/localtunnel/localtunnel

# %%
# !pip install streamlit -q
# Out:
#      |████████████████████████████████| 9.2 MB 34.5 MB/s
#      |████████████████████████████████| 164 kB 71.9 MB/s
#      |████████████████████████████████| 4.7 MB 76.5 MB/s
#      |████████████████████████████████| 78 kB 10.2 MB/s
#      |████████████████████████████████| 184 kB 104.8 MB/s
#      |████████████████████████████████| 238 kB 85.5 MB/s
#      |████████████████████████████████| 62 kB 1.6 MB/s
#      |████████████████████████████████| 51 kB 9.0 MB/s
# ...

# %% [markdown]
# ### Write the cell python code into an app.py file
# - 아래 코드를 생성하면, app.py 파일이 생성된 것을 확인할 수 있다.
# > ![image.png](data:image/png;base64,...)

# %%
# %%writefile app.py
import streamlit as st
st.write('# Hello World')
st.write(## Run Streamlit on Colab withou `ngrok` using `localtunnel`')
# Out:
# Writing app.py

# %% [markdown]
# ### Install localtunnel

# %%
# !pip install pyngrok

# %%
# from pyngrok import ngrok

# %%
# !nohup streamlit run app.py &
# url = ngrok.connect(port = '8501')
# print(url)

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# added 22 packages from 22 contributors and audited 22 packages in 0.872s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities
#
#
#
#    ╭───────────────────────────────────────────────────────────────╮
#    │                                                               │
#    │      New major version of npm available! 6.14.8 → 9.2.0       │
#    │   Changelog: https://github.com/npm/cli/releases/tag/v9.2.0   │
#    │               Run npm install -g npm to update!               │
# ...

# %%
# !npm install -g npm
# Out:
# /tools/node/bin/npm -> /tools/node/lib/node_modules/npm/bin/npm-cli.js
# /tools/node/bin/npx -> /tools/node/lib/node_modules/npm/bin/npx-cli.js
# npm WARN notsup Unsupported engine for npm@9.2.0: wanted: {"node":"^14.17.0 || ^16.13.0 || >=18.0.0"} (current: {"node":"14.16.0","npm":"6.14.8"})
# npm WARN notsup Not compatible with your version of node/npm: npm@9.2.0
#
# + npm@9.2.0
# added 94 packages from 28 contributors, removed 297 packages and updated 137 packages in 5.884s

# %% [markdown]
# ### Run streamlit using localtunnel
# - npm installation would take some time for the first time
# - 아래 코드를 실행하면 나오는 url 을 클릭하면 새 창이 열리는데, 새 창에서 주의사항을 읽어본 후에 [Click to Continue] 를 클릭한다.
# > `your url is: https://some-wolves-fail-34-86-17-127.loca.lt`
# > ![image.png](data:image/png;base64,...)

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/streamlit", line 5, in <module>
#     from streamlit.web.cli import main
#   File "/usr/local/lib/python3.8/dist-packages/streamlit/__init__.py", line 55, in <module>
#     from streamlit.delta_generator import DeltaGenerator as _DeltaGenerator
#   File "/usr/local/lib/python3.8/dist-packages/streamlit/delta_generator.py", line 38, in <module>
#     from streamlit import config, cursor, env_util, logger, runtime, type_util, util
#   File "/usr/local/lib/python3.8/dist-packages/streamlit/cursor.py", line 18, in <module>
#     from streamlit.runtime.scriptrunner import get_script_run_ctx
#   File "/usr/local/lib/python3.8/dist-packages/streamlit/runtime/__init__.py", line 16, in <module>
#     from streamlit.runtime.runtime import Runtime as Runtime
#   File "/usr/local/lib/python3.8/dist-packages/streamlit/runtime/runtime.py", line 26, in <module>
#     from streamlit.proto.BackMsg_pb2 import BackMsg
# ...

# %%
# !streamlit run /content/app.py &>/content/logs.txt &

# %%
# !npx localtunnel --port 8501
# Out:
# npm WARN cli npm v9.2.0 does not
# npm WARN cli support Node.js
# npm WARN cli v14.16.0. You should
# npm WARN cli probably upgrade to a
# npm WARN cli newer version of node
# npm WARN cli as we can't make any
# npm WARN cli promises that npm
# npm WARN cli will work with this
# npm WARN cli version. This version
# npm WARN cli of npm supports the
# npm WARN cli following node
# npm WARN cli versions: `^14.17.0
# npm WARN cli || ^16.13.0 ||
# npm WARN cli >=18.0.0`. You can
# npm WARN cli find the latest
# npm WARN cli version at
# npm WARN cli https://nodejs.org/.
# your url is: https://curly-rooms-sip-34-86-17-127.loca.lt
# ^C

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 위 코드를 실행하면, `"504 Gateway Time-out"` 에러가 뜬 화면이 나오는데, 아래의 링크를 참조하여 에러 를 해결하고자 함.
# - https://stackoverflow.com/questions/74500526/streamlit-via-google-colab-through-localtunnel-does-not-work-anymore
# > ![image.png](data:image/png;base64,...)
# >
# > ``` pip install streamlit==1.13.0 ```
